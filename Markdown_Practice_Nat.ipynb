# %% [markdown]
# <a href="https://colab.research.google.com/github/vonmizn/data-science/blob/Google-Collab-Markdown-Practice-Upload/Markdown_Practice_Nat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Markdown Practice
#
#   - Hello
#     - how are you
#
# #Header One
# ## Header Two
# ### Header Three
#
# ## **Bold Header**
#
# ✈
#
# \Hello
#
# ![Aston.PNG](data:image/png;base64,...)
